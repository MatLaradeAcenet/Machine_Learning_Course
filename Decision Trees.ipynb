# %%
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.model_selection import train_test_split
import numpy as np
iris_attributes, iris_classes = load_iris(return_X_y=True)
attributes_train, attributes_test, classes_train, classes_test = train_test_split(iris_attributes, iris_classes, test_size=0.2, random_state=50)

# %%
Tree1 = tree.DecisionTreeClassifier()

# %%
Tree1  = Tree1.fit(attributes_train, classes_train)

# %%
#the random splitter choses where to split randomly, so we expect performance to degrade
R_Tree1 = tree.DecisionTreeClassifier(splitter="random")

# %%
Tree2 = tree.DecisionTreeClassifier()
Tree2 = Tree2.fit(attributes_train, classes_train)
Tree3 = tree.DecisionTreeClassifier()
Tree3 = Tree3.fit(attributes_train, classes_train)
Tree4 = tree.DecisionTreeClassifier()
Tree4 = Tree4.fit(attributes_train, classes_train)
Tree5 = tree.DecisionTreeClassifier()
Tree5 = Tree5.fit(attributes_train, classes_train)


print('[0 = correct, nonzero = incorrect], "Number of questions wrong"')
print('Tree_1', predict1 - classes_test, ',',  np.sum(predict1 - classes_test))
print('Tree_2', predict2 - classes_test, ',',  np.sum(predict2 - classes_test))
print('Tree_3', predict3 - classes_test, ',',  np.sum(predict3 - classes_test))
print('Tree_4', predict4 - classes_test, ',',  np.sum(predict4 - classes_test))
print('Tree_5', predict5 - classes_test, ',',  np.sum(predict5 - classes_test))
# Out:
# [0 = correct, nonzero = incorrect], "Number of questions wrong"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-88dbd8dca7cb> in <module>
#      10
#      11 print('[0 = correct, nonzero = incorrect], "Number of questions wrong"')
# ---> 12 print('Tree_1', predict1 - classes_test, ',',  np.sum(predict1 - classes_test))
#      13 print('Tree_2', predict2 - classes_test, ',',  np.sum(predict2 - classes_test))
#      14 print('Tree_3', predict3 - classes_test, ',',  np.sum(predict3 - classes_test))
#
# NameError: name 'predict1' is not defined

# %%
predict1 = Tree1.predict(attributes_test)
predict2 = Tree2.predict(attributes_test)
predict3 = Tree3.predict(attributes_test)
predict4 = Tree4.predict(attributes_test)
predict5 = Tree5.predict(attributes_test)
print('Tree_1     ', predict1)
print('Tree_2     ', predict2)
print('Tree_3     ', predict3)
print('Tree_4     ', predict4)
print('Tree_5     ', predict5)
print('True_Values', classes_test)

# %% [markdown]
# Plot out the trees to see how each fits the data without being identical

# %%
tree.plot_tree(Tree1)

# %%
tree.plot_tree(Tree2)
# Out:
# [Text(198.4, 338.79999999999995, 'X[2] <= 2.45\nentropy = 0.666\nsamples = 120\nvalue = [41, 38, 41]'),
#  Text(148.8, 277.2, 'entropy = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(248.0, 277.2, 'X[3] <= 1.65\nentropy = 0.499\nsamples = 79\nvalue = [0, 38, 41]'),
#  Text(99.2, 215.59999999999997, 'X[2] <= 4.95\nentropy = 0.176\nsamples = 41\nvalue = [0, 37, 4]'),
#  Text(49.6, 154.0, 'entropy = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(148.8, 154.0, 'X[3] <= 1.55\nentropy = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(99.2, 92.39999999999998, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(198.4, 92.39999999999998, 'X[2] <= 5.45\nentropy = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(148.8, 30.80000000000001, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(248.0, 30.80000000000001, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(396.8, 215.59999999999997, 'X[2] <= 4.85\nentropy = 0.051\nsamples = 38\nvalue = [0, 1, 37]'),
# ...

# %%
tree.plot_tree(Tree3)
# Out:
# [Text(133.92000000000002, 199.32, 'X[3] <= 0.8\nentropy = 0.666\nsamples = 120\nvalue = [41, 38, 41]'),
#  Text(100.44000000000001, 163.07999999999998, 'entropy = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(167.40000000000003, 163.07999999999998, 'X[3] <= 1.65\nentropy = 0.499\nsamples = 79\nvalue = [0, 38, 41]'),
#  Text(66.96000000000001, 126.83999999999999, 'X[2] <= 4.95\nentropy = 0.176\nsamples = 41\nvalue = [0, 37, 4]'),
#  Text(33.480000000000004, 90.6, 'entropy = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(100.44000000000001, 90.6, 'X[3] <= 1.55\nentropy = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(66.96000000000001, 54.359999999999985, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(133.92000000000002, 54.359999999999985, 'X[0] <= 6.6\nentropy = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(100.44000000000001, 18.119999999999976, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
# ...

# %%
tree.plot_tree(Tree4)
# Out:
# [Text(133.92000000000002, 199.32, 'X[3] <= 0.8\nentropy = 0.666\nsamples = 120\nvalue = [41, 38, 41]'),
#  Text(100.44000000000001, 163.07999999999998, 'entropy = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(167.40000000000003, 163.07999999999998, 'X[3] <= 1.65\nentropy = 0.499\nsamples = 79\nvalue = [0, 38, 41]'),
#  Text(66.96000000000001, 126.83999999999999, 'X[2] <= 4.95\nentropy = 0.176\nsamples = 41\nvalue = [0, 37, 4]'),
#  Text(33.480000000000004, 90.6, 'entropy = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(100.44000000000001, 90.6, 'X[3] <= 1.55\nentropy = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(66.96000000000001, 54.359999999999985, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(133.92000000000002, 54.359999999999985, 'X[1] <= 2.85\nentropy = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(100.44000000000001, 18.119999999999976, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
# ...

# %%
tree.plot_tree(Tree5)
# Out:
# [Text(133.92000000000002, 199.32, 'X[2] <= 2.45\nentropy = 0.666\nsamples = 120\nvalue = [41, 38, 41]'),
#  Text(100.44000000000001, 163.07999999999998, 'entropy = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(167.40000000000003, 163.07999999999998, 'X[3] <= 1.65\nentropy = 0.499\nsamples = 79\nvalue = [0, 38, 41]'),
#  Text(66.96000000000001, 126.83999999999999, 'X[2] <= 4.95\nentropy = 0.176\nsamples = 41\nvalue = [0, 37, 4]'),
#  Text(33.480000000000004, 90.6, 'entropy = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(100.44000000000001, 90.6, 'X[3] <= 1.55\nentropy = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(66.96000000000001, 54.359999999999985, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(133.92000000000002, 54.359999999999985, 'X[1] <= 2.85\nentropy = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(100.44000000000001, 18.119999999999976, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
# ...
